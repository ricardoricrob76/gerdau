# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoricrob76/gerdau/blob/main/GERDAU_Aula_06_SkLearning_Modelos_de_Classifica%C3%A7%C3%A3o_Sele%C3%A7%C3%A3o_de_Features_Matriz_de_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GERDAU - Treinamento InCompany
# Autor:  Profº - Ricardo Roberto de Lima - FABWORK
# Ciência de Dados com Python + Pandas, Numpy, SkLearning. Diabetes
# Machine Learning - Aula 06 - Modelos de Classificação - Seleção de Features.
#  - Seleção das Melhores Features em Matriz de Correlação.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Adaptar para o Ambiente da GERDAU.
# import awswrangler as wr

# import boto3
# boto3.setup_default_session(region_name="us-east-2")

data = pd.read_csv("train.csv")

# Criar um Objeto do tipo DataFrame no Ambiente Big Data - Gerdau
# data=wr.s3.read_csv('s3://gerdau-analytics/gdata/datascience/train.csv')

# %%
# Criar um Objeto do tipo DataFrame no Ambiente Big Data - Gerdau
# data=wr.s3.read_csv('s3://gerdau-analytics/gdata/datascience/train.csv')

data = pd.read_csv("train.csv")
X = data.iloc[:,0:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range

# %%
#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(100,100))

# %%
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
