# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoricrob76/gerdau/blob/main/Aula02_Unifacisa_Projeto_Integrador_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Curso: ADS - UNIFACISA - 2025.2
# Autor: Ricardo Roberto de Lima.
# Identificando os valores com forte Correlação e Fraca correlação entre si.

# %% [markdown]
# <P> Em probabilidade e estatística, correlação, dependência ou associação é qualquer relação estatística entre duas variáveis.<br>
#
# <p>Resume o grau de relacionamento entre duas variáveis (X e Y, por exemplo). O objetivo do estudo da correlação é determinar (mensurar) o grau de relacionamento entre duas variáveis.<br>
#
# <p>O valor do coeficiente de correlação pode variar entre -1 e 1 e o resultado obtido define se a correlação é negativa ou positiva. Para interpretar o coeficiente é preciso saber que 1 significa que a correlação entre as variáveis é perfeita positiva e -1 significa que é perfeita negativa. Se o coeficiente for igual a 0 significa que as variáveis não dependem uma da outra.
#
# <p>Importante: CORREÇÃO NÃO SIGNIFICA CAUSALIDADE<br>

# %%
# importar as principais bibliotecas de ciência dados para python.
import pandas as pd  # planilha eletrônica e todas as suas operações.
import seaborn as sns # componente de visualização de dados no formato HTML.
import matplotlib.pyplot as plt # biblioteca de visualização 2D e 3D para ciência de dados

# %%
# Criando um novo dataframe para coletas os dados e analisar.
df = pd.read_excel("dataset.xlsx")

# %%
# Visualizando as primeiras 10 linhas do dataframe
df.head(10)
# Out:
#   Modelo   Ano  Cilindradas  Cavalos  Consumo_Litro_Km  Peso_kg  Km_Rodados  \
# 0    Gol  2015         1000      110                12     1300       13150
# 1    Gol  2016         1000      110                12     1300       13000
# 2    Gol  2017         1000      110                12     1300       12850
# 3    Gol  2018         1000      110                12     1300       12700
# 4    Gol  2019         1000      110                12     1300       12550
# 5    Gol  2020         1000      110                12     1300       12400
# 6  Palio  2015         1000      110                12     1400       12250
# 7  Palio  2016         1000      110                12     1400       12100
# 8  Palio  2017         1000      110                12     1400       11950
# 9  Palio  2018         1000      110                12     1400       11800
#
#    ValorTabela
# 0        25000
# 1        35000
# 2        45000
# 3        55000
# 4        75000
# 5        98000
# 6        25000
# ...

# %%
# Visualizando as últimas 10 linhas do dataframe
df.tail(15)
# Out:
#      Modelo   Ano  Cilindradas  Cavalos  Consumo_Litro_Km  Peso_kg  \
# 86     Golf  2018         2000      140                 6     2400
# 87     Golf  2019         2000      140                 6     2400
# 88     Golf  2020         2000      140                 6     2400
# 89   Vectra  2015         2000      140                 6     2400
# 90   Vectra  2016         2000      140                 6     2400
# 91   Vectra  2017         2000      140                 6     2400
# 92   Vectra  2018         2000      140                 6     2400
# 93   Vectra  2019         2000      140                 6     2400
# 94   Vectra  2020         2000      140                 6     2400
# 95   BMW X1  2015         2400      210                 4     2400
# 96   BMW X1  2016         2400      210                 4     2400
# 97   BMW X1  2017         2400      210                 4     2400
# 98   BMW X1  2018         2400      210                 4     2400
# ...

# %%
df = df.drop(columns=['Modelo'])

# %%
df.head()
# Out:
#     Ano  Cilindradas  Cavalos  Consumo_Litro_Km  Peso_kg  Km_Rodados  \
# 0  2015         1000      110                12     1300       13150
# 1  2016         1000      110                12     1300       13000
# 2  2017         1000      110                12     1300       12850
# 3  2018         1000      110                12     1300       12700
# 4  2019         1000      110                12     1300       12550
#
#    ValorTabela
# 0        25000
# 1        35000
# 2        45000
# 3        55000
# 4        75000

# %%
# Neste caso podemos dizer que a CORRELAÇÃO É NEUTRA OU NULA ou que Não existe CORRELAÇÃO entre essas variáveis.
sns.lmplot(x = "Ano", y = "Cilindradas", data = df);

# %%
# Neste caso podemos dizer que existe uma CORRELAÇÃO FORTE POSITIVA entre essas variáveis
# Na medida que a variável X aumenta a variável Y também aumenta
sns.lmplot(x = "Ano", y = "ValorTabela", data = df);

# %%
# Neste caso podemos dizer que existe uma CORRELAÇÃO FORTE NEGATIVA entre essas variáveis
# Na medida que a variável X aumenta a variável Y diminui
sns.lmplot(x = "Consumo_Litro_Km", y = "Cilindradas", data = df);

# %%
# Através do hitmap podemos observar a correlação entre todas variáveis.
plt.rcParams["figure.figsize"] = (18,8)
ax = sns.heatmap(df.corr(), annot=True)

# %%
# Neste caso podemos dizer que existe uma CORRELAÇÃO FORTE NEGATIVA entre essas variáveis
# Na medida que a variável X aumenta a variável Y diminui
sns.lmplot(x = "Consumo_Litro_Km", y = "Km_Rodados", data = df);

# %%
# Neste caso podemos dizer que existe uma CORRELAÇÃO FORTE NEGATIVA entre essas variáveis
# Na medida que a variável X aumenta a variável Y diminui
sns.lmplot(x = "Consumo_Litro_Km", y = "Peso_kg", data = df);
